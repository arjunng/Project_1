# %%
 #Set up
import pandas as pd

#Load File
load_file = "Data/Inv_Hap.csv"

#Read File
file = pd.read_csv(load_file)

# %%
# PR = Political Rights
# CL = Civil Liberties


#Show DF
file
# Out:
#          Country                           Region  Population  Happiness_Rank  \
# 0    Afghanistan                    Southern Asia  33736494.0             153
# 1        Albania       Central and Eastern Europe   2880703.0              95
# 2        Algeria  Middle East and Northern Africa  39871528.0              68
# 3         Angola               Sub-Saharan Africa  27859305.0             137
# 4      Argentina      Latin America and Caribbean  43417765.0              30
# ..           ...                              ...         ...             ...
# 147    Venezuela      Latin America and Caribbean  31155134.0              23
# 148      Vietnam                Southeastern Asia  91713300.0              75
# 149        Yemen  Middle East and Northern Africa  26916207.0             136
# 150       Zambia               Sub-Saharan Africa  16100587.0              85
# 151     Zimbabwe               Sub-Saharan Africa  15777451.0             115
#
# ...
